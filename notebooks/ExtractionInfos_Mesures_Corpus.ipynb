# %%
from glob import glob
import glob
import nltk
import random
random.seed(42)
import jieba

# %%
# Initialiser une liste pour stocker le contenu de tous les documents français
all_fr_text = []
# Initialiser une liste pour stocker les phrases de tous les documents français
all_fr_sentences = []
# Initialiser une liste pour stocker les tokens de chaque document français
#tokenized_docs_fr = []

# Parcourir tous les fichiers "Fr*.txt"
for infile in glob.glob("../Corpus/Fr*.txt"):
    with open(infile, encoding='utf-8') as f:  # S'assurer de spécifier l'encodage si nécessaire
        text = f.read()
        all_fr_text.append(text)
        # Convertir le générateur de phrases en liste et l'ajouter à la liste des phrases
        all_fr_sentences.extend(nltk.sent_tokenize(text))

# Concaténer le contenu de tous les documents fr en un seul document
concatenated_text_fr = '\n'.join(all_fr_text)

# Tokenizer le texte
tokens_fr = nltk.word_tokenize(concatenated_text_fr)
# Liste de token du texte
#tokenized_docs_fr.append(tokens_fr)

# Calculer la taille en nombre de jetons
token_fr_count = len(tokens_fr)

# Afficher le nombre de tokens
print("Nombre total de tokens dans les documents fr:", token_fr_count)
#print("Liste de tous les tokens des documents fr:", tokenized_docs_fr)
#print(len(tokenized_docs_fr))
# Afficher le nombre de phrases
print("Nombre total de phrases dans les documents français:", len(all_fr_sentences))
# Afficher les premières phrases (facultatif)
print("Premières phrases dans les documents français:")
for sentence in all_fr_sentences[:5]:
    print(sentence)
# Out:
# Nombre total de tokens dans les documents fr: 70008
# Nombre total de phrases dans les documents français: 2230
# Premières phrases dans les documents français:
#
# L’histoire est à la fois l'étude et l'écriture des faits et des événements passés quelles que soient leur variété et leurs complexités.
# Ce mot est souvent écrit avec la première lettre en majuscule.
# L'histoire est également une science humaine et sociale.
# On désigne aussi couramment sous le terme d'histoire (par synecdoque) le passé lui-même, comme dans les leçons de l'histoire.
# L'histoire est un récit écrit par lequel les êtres humains, et plus particulièrement les historiens, s'efforcent de faire connaître les temps révolus.

# %%
concatenated_text_fr
# Out:
# '\nL’histoire est à la fois l\'étude et l\'écriture des faits et des événements passés quelles que soient leur variété et leurs complexités. Ce mot est souvent écrit avec la première lettre en majuscule. L\'histoire est également une science humaine et sociale. On désigne aussi couramment sous le terme d\'histoire (par synecdoque) le passé lui-même, comme dans les leçons de l\'histoire. L\'histoire est un récit écrit par lequel les êtres humains, et plus particulièrement les historiens, s\'efforcent de faire connaître les temps révolus. Ces tentatives ne sont jamais entièrement indépendantes de conditionnements étrangers au domaine telle que la vision du monde de leur auteur ou sa culture, mais elles sont censées être élaborées à partir de sources plutôt que guidées par la spéculation ou l\'idéologie.\n\nAu cours des siècles, les historiens ont façonné leurs méthodes ainsi que les champs d\'intervention, tout en réévaluant leurs sources, leur origine et leur exploitation. La discipli
# ...

# %%
tokens_fr
# Out:
# ['L',
#  '’',
#  'histoire',
#  'est',
#  'à',
#  'la',
#  'fois',
#  "l'étude",
#  'et',
#  "l'écriture",
#  'des',
#  'faits',
#  'et',
#  'des',
#  'événements',
#  'passés',
#  'quelles',
#  'que',
#  'soient',
#  'leur',
#  'variété',
#  'et',
#  'leurs',
#  'complexités',
#  '.',
#  'Ce',
#  'mot',
#  'est',
#  'souvent',
#  'écrit',
#  'avec',
#  'la',
#  'première',
#  'lettre',
#  'en',
#  'majuscule',
#  '.',
#  "L'histoire",
#  'est',
#  'également',
#  'une',
#  'science',
#  'humaine',
#  'et',
#  'sociale',
#  '.',
#  'On',
#  'désigne',
#  'aussi',
#  'couramment',
#  'sous',
#  'le',
#  'terme',
#  "d'histoire",
#  '(',
#  'par',
#  'synecdoque',
#  ')',
#  'le',
#  'passé',
#  'lui-même',
#  ',',
#  'comme',
#  'dans',
#  'les',
#  'leçons',
#  'de',
#  "l'histoire",
#  '.',
#  "L'histoire",
#  'est',
#  'un',
#  'récit',
#  'écrit',
#  'par',
#  'lequel',
#  'les',
#  'êtres',
#  'humains',
#  ',',
#  'et',
#  'plus',
#  'particulièrement',
#  'les',
# ...

# %%
# Initialiser une liste pour stocker le contenu de tous les documents anglais
all_en_text = []
# Initialiser une liste pour stocker les phrases de tous les documents anglais
all_en_sentences = []

# Parcourir tous les fichiers "En*.txt"
for infile in glob.glob("../Corpus/Anglais*.txt"):
    with open(infile, encoding='utf-8') as f:  # S'assurer de spécifier l'encodage si nécessaire
        text = f.read()
        all_en_text.append(text)
        all_en_sentences.extend(nltk.sent_tokenize(text))

# Concaténer le contenu de tous les documents anglais en un seul document
concatenated_text_en = '\n'.join(all_en_text)

# Tokenizer le texte
tokens_en = nltk.word_tokenize(concatenated_text_en)

# Calculer la taille en nombre de jetons
token_en_count = len(tokens_en)

# Afficher le nombre de tokens
print("Nombre total de tokens dans les documents anglais:", token_en_count)

# Afficher le nombre de phrases
print("Nombre total de phrases dans les documents anglais:", len(all_en_sentences))

# Afficher les premières phrases (facultatif)
print("Premières phrases dans les documents anglais:")
for sentence in all_en_sentences[:5]:
    print(sentence)
# Out:
# Nombre total de tokens dans les documents anglais: 39893
# Nombre total de phrases dans les documents anglais: 1416
# Premières phrases dans les documents anglais:
# Music
# For other uses, see Music (disambiguation).
# In the most general of terms, music is the arrangement of sound to create some combination of form, harmony, melody, rhythm, or otherwise expressive content.
# [1][2][3] Definitions of music vary depending on culture,[4] though it is an aspect of all human societies and a cultural universal.
# [5] While scholars agree that music is defined by a few specific elements, there is no consensus on their precise definitions.
# [6] The creation of music is commonly divided into musical composition, musical improvisation, and musical performance,[7] though the topic itself extends into academic disciplines, criticism, philosophy, psychology, and therapeutic contexts.

# %%
concatenated_text_en
# Out:
# 'Music\nFor other uses, see Music (disambiguation).\nIn the most general of terms, music is the arrangement of sound to create some combination of form, harmony, melody, rhythm, or otherwise expressive content.[1][2][3] Definitions of music vary depending on culture,[4] though it is an aspect of all human societies and a cultural universal.[5] While scholars agree that music is defined by a few specific elements, there is no consensus on their precise definitions.[6] The creation of music is commonly divided into musical composition, musical improvisation, and musical performance,[7] though the topic itself extends into academic disciplines, criticism, philosophy, psychology, and therapeutic contexts. Music may be performed using a vast range of instruments, including the human voice to sing, and thus is often credited for its extreme versatility and opportunity for creativity.[8]\n\nIn some musical contexts, a performance or composition may be to some extent improvised. For instance
# ...

# %%
# Initialiser une liste pour stocker le contenu de tous les documents chinois
#all_zh_text = []
# Initialiser une liste pour stocker les phrases de tous les documents chinois
#all_zh_sentences = []

# Parcourir tous les fichiers "Zh*.txt"
#for infile in glob.glob("../Corpus/Ch*.txt"):
    #with open(infile, encoding='utf-8') as f:  # S'assurer de spécifier l'encodage si nécessaire
        #text = f.read()
        #all_zh_text.append(text)
        
        
        
        
        
        
        # Convertir le générateur de phrases en liste et l'ajouter à la liste des phrases
        #all_zh_sentences.extend(nltk.sent_tokenize(text))
        # Tokenization du texte en phrases avec NLTK
        #sentences = nltk.sent_tokenize(text)
        # Ajouter les phrases à la liste des phrases
        #all_zh_sentences.extend(sentences)

# Concaténer le contenu de tous les documents chinois en un seul document
#concatenated_text_zh = '\n'.join(all_zh_text)

# Tokenizer le texte
#tokens_zh = nltk.word_tokenize(concatenated_text_zh)

# Calculer la taille en nombre de jetons
#token_zh_count = len(tokens_zh)
# Afficher le nombre de tokens
#print("Nombre total de tokens dans les documents chinois:", token_zh_count)

# Afficher le nombre de phrases
#print("Nombre total de phrases dans les documents chinois:", len(all_zh_sentences))

# Afficher les premières phrases (facultatif)
#print("Premières phrases dans les documents chinois:")
#for sentence in all_zh_sentences[:5]:
    #print(sentence)        
        

        
        
        
        
        # Tokenization du texte avec Jieba
        #tokens_zh = jieba.cut(text)
        # Convertir le générateur de phrases en liste et l'ajouter à la liste des phrases
        #all_zh_sentences.extend(list(sentences))
        
        # Tokenization du texte en phrases avec NLTK
        #sentences = nltk.sent_tokenize(text)
        # Ajouter les phrases à la liste des phrases
       # all_zh_sentences.extend(sentences)

# Concaténer le contenu de tous les documents chinois en un seul document
#concatenated_text_zh = '\n'.join(all_zh_text)

# Tokenizer le texte en mots avec Jieba
#tokens_zh = jieba.cut(concatenated_text_zh)
# Convertir le générateur en liste pour obtenir les jetons
#token_list_zh = list(tokens_zh)

# Calculer la taille en nombre de jetons
#token_zh_count = len(token_list_zh)
# Calculer la taille en nombre de jetons
#words = list(tokens_zh)
#len(words)

# Calculer le nombre de phrases
#num_zh_sentences = len(all_zh_sentences)
# Calculer le nombre de phrases
#num_zh_sentences = sum(1 for _ in all_zh_sentences)

# Afficher le nombre de tokens
#print("Nombre total de tokens dans les documents chinois:", token_zh_count)

# Afficher le nombre de phrases
#print("Nombre total de phrases dans les documents chinois:", num_zh_sentences)

# Afficher les premières phrases (facultatif)
#print("Premières phrases dans les documents chinois:")
#for sentence in all_zh_sentences[:5]:
    #print(sentence)

# %%
# Initialiser une liste pour stocker le contenu de tous les documents chinois
#all_zh_text = []
# Initialiser une liste pour stocker les phrases de tous les documents chinois
#all_zh_sentences = []

# Parcourir tous les fichiers "Zh*.txt"
for infile in glob.glob("../Corpus/Ch*.txt"):
    with open(infile, encoding='utf-8') as f:  # S'assurer de spécifier l'encodage si nécessaire
        text = f.read()
        # Tokenization du texte avec Jieba
        tokens_zh = jieba.cut(text)
        
# Calculer la taille en nombre de tokens
words_zh = list(tokens_zh)
# Afficher le nombre de tokens
print("Nombre total de tokens dans les documents chinois :", len(words_zh))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.580 seconds.
# Prefix dict has been built successfully.
# Nombre total de tokens dans les documents chinois : 11062

# %%
# Récupérer la liste des chemins des fichiers commençant par "Ch" dans le répertoire spécifié
file_paths_zh = glob.glob("../Corpus/Ch*.txt")

# Fonction pour découper le texte en phrases
def segment_texts_to_sentences_from_files(file_paths_zh):
    all_sentences = []
    # Parcourir tous les chemins de fichiers
    for file_path in file_paths_zh:
        # Ouvrir le fichier et lire le texte
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()
        # Découper le texte en phrases avec Jieba
        words = list(jieba.cut(text))
        sentences = []
        # Initialiser une phrase vide
        sentence = []
        # Parcourir tous les mots
        for word in words:
            # Si le mot est une ponctuation qui indique la fin d'une phrase
            if word in ['。', '？', '！']:
                # Ajouter la phrase courante à la liste des phrases
                sentences.append(''.join(sentence))
                # Réinitialiser la phrase courante
                sentence = []
            else:
                # Ajouter le mot à la phrase courante
                sentence.append(word)
        # Si la phrase finale n'est pas vide, l'ajouter à la liste des phrases
        if sentence:
            sentences.append(''.join(sentence))
        # Ajouter les phrases du document courant à la liste de toutes les phrases
        all_sentences.extend(sentences)
    return all_sentences

# Exemple d'utilisation avec les fichiers commençant par "Ch"
sentences_zh = segment_texts_to_sentences_from_files(file_paths_zh)
#print(sentences)
# Afficher le nombre de phrases
print("Nombre total de phrases dans les documents chinois:", len(sentences_zh))
# Out:
# Nombre total de phrases dans les documents chinois: 1611

# %%
#concatenated_text_zh   
print(sentences_zh)
# Out:
# ['电影\n維基媒體專案貢獻者\n6–7 minutes\n一段顯示一匹馬飛奔，騎在它背上的騎師的動畫片斷\n1878年由埃德沃德·邁布里奇拍攝的一組照片的GIF動畫\n一部早期的電影放映機\n時長：3 秒', '\n世界上第一部電影--《郎德海花園場景》\n1912年的動畫短片《蚊子是怎麼生活的》是歷史上最早的動畫電影之一\n時長：10 分，13 秒', '\n卓別林的電影《債券》\n\n電影（英語：movie/ film），特點是運動／移動的畫面（英語：motion/ moving picture），是一種視覺藝術作品，用來模擬透過使用動態圖像來傳達思想、故事、感知、感覺、美或氛圍的體驗', '這些圖像通常伴有聲音，更少有其他感官刺激', '[1]\n\n電影中看起來連續的畫面，是由一幀幀單獨的照片完成的，至於關於電影中運動的感覺，是因為人們因為視覺上的飛現象（Phi phenomenon），使得對一連串靜態圖片卻會造成移動的錯覺', '傳統對電影中運動感知的理解是因為視覺暫留，使得圖像離開後，仍能在眼睛保留「視像」約十分之一秒', '因此大腦感覺到圖像是「運動」的', '但在1916年出版的德國心理學家雨果·明斯特伯格（Hugo Münsterberg）的《電影：一次心理學研究》中第三章《深度感和運動感》中，雨果·明斯特伯格證明了外觀運動絕不是影像滯留（即視覺暫留）的結果，而是（但不僅僅是）對運動的連續階段的感知', '\n\n電影製作本身是藝術也是產業', '電影可以由電影攝影機拍攝真實影像再製作而成，也可以利用傳統的動畫技巧繪製圖畫再拍攝圖畫而成，甚至可以利用電腦成像及計算機動畫製作電影，也可以在電影中利用上述所有的技術及其他視覺效果', '電影技術發展初期有各種不同的放映速度，但現時電影都多以每秒二十四格圖像作放映標準[2]', '\n\n路易斯·普林斯於1888年10月14日，使用改進版的單鏡頭攝影機（即MkII）拍攝了電影《朗德海花園場景》', '他在里茲的漢斯萊特區的惠特利工廠以及惠特利位於朗德海的家--奧克伍德農莊展出了他這第一部電影', '\n\n電影成為第七藝術的來由是義大利詩人和電影先驅者喬托·卡努杜（Ricciotto Canudo），他在於1911年發表的一篇《第六藝術的誕生》（Birth of the 6th art），將電影放在
# ...

# %%
# Split the corpus in 3 parts : dev, train and test for the 3 languages
# 10% for dev, 80% for train, 10% for test



# dev
len_dev_fr = int(len(all_fr_sentences) * 0.1)
print("Nombre total de phrases dans les documents français:", len(all_fr_sentences))
#print(len_dev_fr)
print("\n")

len_dev_en = int(len(all_en_sentences) * 0.1)
print("Nombre total de phrases dans les documents anglais:", len(all_en_sentences))
#print(len_dev_en)
print("\n")

len_dev_zh = int(len(sentences_zh) * 0.1)
print("Nombre total de phrases dans les documents chinois:", len(sentences_zh))
#print(len_dev_zh)
print("\n")
#print(len_docs)
#print(len_dev)


dev_fr = random.sample(all_fr_sentences, len_dev_fr)
remain_fr = [d for d in all_fr_sentences if d not in dev_fr]
#print(len(remain_fr))
#print(len(dev_fr))
#print("\n")

dev_en = random.sample(all_en_sentences, len_dev_en)
remain_en = [d for d in all_en_sentences if d not in dev_en]

dev_zh = random.sample(sentences_zh, len_dev_zh)
remain_zh = [d for d in sentences_zh if d not in dev_zh]
#print(len(remain))


# test
test_fr = random.sample(remain_fr, len_dev_fr)
test_en = random.sample(remain_en, len_dev_en)
test_zh = random.sample(remain_zh, len_dev_zh)
#print(len(test))



# train
train_fr = [d for d in remain_fr if d not in test_fr]
train_en = [d for d in remain_en if d not in test_en]
train_zh = [d for d in remain_zh if d not in test_zh]

print(f"Len dev_fr : {len(dev_fr)}, len test_fr : {len(test_fr)}, len train_fr : {len(train_fr)}")
print(f"Len dev_en : {len(dev_en)}, len test_en : {len(test_en)}, len train_en : {len(train_en)}")
print(f"Len dev_zh : {len(dev_zh)}, len test_zh : {len(test_zh)}, len train_zh : {len(train_zh)}")
# Out:
# Nombre total de phrases dans les documents français: 2230
#
#
# Nombre total de phrases dans les documents anglais: 1416
#
#
# Nombre total de phrases dans les documents chinois: 1611
#
#
# Len dev_fr : 223, len test_fr : 223, len train_fr : 1776
# Len dev_en : 141, len test_en : 141, len train_en : 1123
# Len dev_zh : 161, len test_zh : 161, len train_zh : 1015

# %%
print(dev_fr)
# Out:
# ['Actuellement, du fait d’une consommation excessive d’engrais et de pesticides, la plupart des sols cultivés de nos jours subissent les contre coûts de ces excès passés.', "Afin de comprendre l'évolution des paysages et des structures agraires, Marc Bloch a étudié les cadastres du XIXe siècle.", 'Un procédé encore plus économique, découvert en photographie dans les années 1920, est adapté au cinéma en Italie dans les années 1950 : le Ferraniacolor.', "Cette réserve permet d'affirmer que Georges Méliès n’est pas, contrairement à ce qui est souvent dit, l’inventeur de la fiction, alors que son apport technique, comme illusionniste, est considérable, notamment avec l'arrêt de caméra, un procédé qu'il reprend à William Heise et Alfred Clark, de l'équipe d'Edison qui ont tourné L'Exécution de Mary, reine des Écossais en 1895.", 'Les projections du Théâtre optique et les réactions du public l’ont convaincu aussi que l’avenir n’est pas dans le kinétoscope, vu par un seul spectateur à la fo
# ...

# %%
print(test_fr)
# Out:
# ['En outre, ce matériel publicitaire aidera l’exploitant à vendre des billets.', 'Cependant, il existe quelques prix qui félicitent le succès commercial, comme le Goldene Leinwand (la toile d’or) en Allemagne qui récompensait chaque film de plus de 3 000 000 de spectateurs[199].', "Il prend aussi le sens général d'histoire (au sens de récit), polysémie qu'il a conservée jusqu'à ce jour en français comme en allemand.", 'En 1956 est publiée une théorisation de la musique stochastique qui s’appuie entre autres sur la théorie des jeux de von Neumann.', 'Le son fut donc très vite intégré, de manière optique, sur le bord de la pellicule[253].', "Depuis la généralisation des moyens techniques d'enregistrement du son, l'œuvre peut également s'identifier à son support : l'album de musique, la bande magnétique ou à une simple calligraphie de la représentation du geste musical propre à transcrire l'œuvre du compositeur.", 'La pellicule argentique serait-elle en train de vivre ses derniers momen
# ...

# %%
print(train_fr)
# Out:
# ["\nL’histoire est à la fois l'étude et l'écriture des faits et des événements passés quelles que soient leur variété et leurs complexités.", 'Ce mot est souvent écrit avec la première lettre en majuscule.', "On désigne aussi couramment sous le terme d'histoire (par synecdoque) le passé lui-même, comme dans les leçons de l'histoire.", "L'histoire est un récit écrit par lequel les êtres humains, et plus particulièrement les historiens, s'efforcent de faire connaître les temps révolus.", "Ces tentatives ne sont jamais entièrement indépendantes de conditionnements étrangers au domaine telle que la vision du monde de leur auteur ou sa culture, mais elles sont censées être élaborées à partir de sources plutôt que guidées par la spéculation ou l'idéologie.", "Au cours des siècles, les historiens ont façonné leurs méthodes ainsi que les champs d'intervention, tout en réévaluant leurs sources, leur origine et leur exploitation.", "La discipline universitaire d'étude et écriture de l'histoire
# ...

# %%
print(dev_en)
# Out:
# ['Certain cinematographers, such as Christopher Doyle, are well known for their innovative use of filters; Doyle was a pioneer for increased usage of filters in movies and is highly respected throughout the cinema world.', '[15]\n\nTypical Ethiopian and Eritrean cuisine: Injera (thin pancake-like bread) and several kinds of wat (stew)\nA Ramadan dinner in Tanzania\nYassa is a popular dish throughout West Africa prepared with chicken or fish.', 'Black and white cinematography is a technique used in filmmaking where the images are captured and presented in shades of gray, without color.', 'Expression is achieved through the manipulation of pitch (such as inflection, vibrato, slides etc.', 'Although writers of lists of "rudimentary elements of music" can vary their lists depending on their personal (or institutional) priorities, the perceptual elements of music should consist of an established (or proven) list of discrete elements which can be independently manipulated to achieve an int
# ...

# %%
print(test_en)
# Out:
# ['[222] Emissions of nitrous oxide, methane make up over half of total greenhouse gas emission from agriculture.', '[245] In the United States, and elsewhere, food costs attributed to food processing, distribution, and agricultural marketing, sometimes referred to as the value chain, have risen while the costs attributed to farming have declined.', 'Institutional\n\nPeople aiming to become professional musicians, singers, composers, songwriters, music teachers and practitioners of other music-related professions such as music history professors, sound engineers, and so on study in specialized post-secondary programs offered by colleges, universities and music conservatories.', 'Creation\n\nComposition\n\nMain article: Musical composition\n"Composition" is the act or practice of creating a song, an instrumental music piece, a work with both singing and instruments, or another type of music.', 'The vegetarianism practiced in much of India has made pulses (crops harvested solely for the
# ...

# %%
print(train_en)
# Out:
# ['Music\nFor other uses, see Music (disambiguation).', 'In the most general of terms, music is the arrangement of sound to create some combination of form, harmony, melody, rhythm, or otherwise expressive content.', '[1][2][3] Definitions of music vary depending on culture,[4] though it is an aspect of all human societies and a cultural universal.', '[5] While scholars agree that music is defined by a few specific elements, there is no consensus on their precise definitions.', '[6] The creation of music is commonly divided into musical composition, musical improvisation, and musical performance,[7] though the topic itself extends into academic disciplines, criticism, philosophy, psychology, and therapeutic contexts.', 'Music may be performed using a vast range of instruments, including the human voice to sing, and thus is often credited for its extreme versatility and opportunity for creativity.', '[8]\n\nIn some musical contexts, a performance or composition may be to some extent im
# ...

# %%
print(dev_zh)
# Out:
# ['[209]\n\n在所有農業溫室氣體中，57%與動物食物生產相關，29%與植物食物生產相關', '有些人認為因為電影營銷如此激烈，資金充足，電影評論者很難影響電影的票房', '在中世紀和文藝復興時期，人們通常通過神聖或宗教觀點來研究歷史', '歷史可提供今人理解過去，作為未來行事的參考依據，與倫理、哲學和藝術同屬人類精神文明的重要成果', '在重訂章程後，尋常小學依日本語改稱初等小學，而史學、輿地二科，則改稱歷史、地理', '然而，殺蟲劑的廣泛使用並未顯著減少害蟲對農業造成的損失', '魯道夫·阿恩海姆、貝拉·巴拉茲及齊格弗里德·科拉考爾開始的形式主義電影理論強調電影和現實的不同，因此可以視為是美術', '」[12]\n    柯林武德說：「一切歷史都是思想史', '[181]\n土地與水資源問題[編輯]\n位於美國堪薩斯州的灌溉土地，其中綠色的為生長良好的玉米和高粱農田（高粱顏色略淺），金色的是小麥，最近被收割、耕種或休耕的土地為灰色\n\n人類對土地的轉化，也即把自然土地轉變為農業生產服務用地，可對地球生態系造成巨大影響，並引發生物多樣性喪失', '這占到全球兒童勞動力的70%，農業在許多國家也是女性從業比例最高的行業', '[240]\n農業科學[編輯]\n\n農業科學是一門跨學科的領域，涉及自然科學、經濟學和社會科學等相關理論，應用於農業研究與實踐中', '[198]\n殺蟲劑使用[編輯]\n在農田中播撒殺蟲劑\n\n自1950年代起，殺蟲劑的使用日益增多，如今年度使用量已達到230萬噸', '[119]家庭中6歲以下兒童尤其可能遭受農業傷害[120]，常見的事故原因包括溺水、機械或引擎事故、農用車輛側翻等', '畜牧業擴張被認為是造成森林砍伐的主要原因', '[36]\n\n在20世紀，學術歷史學家較少關注史詩般的民族主義敘事，而這些敘事往往傾向於美化國家或偉人理論，對社會和知識力量進行更為客觀和複雜的分析', '中國歷史自傳說中的黃帝以來已經有4千多年，而自西周共和時代（前841年）以來歷史記錄精確到年，自魯隱公元年（前722年）以來則精確到月日', '\n\n    腳本發展\n    前期製作\n    電影製作\n    後期製作\n    電影發行\n\n一般一部電影會需要三年的時間，頭一年腳本發展，第二年是前期製作及電影製作，第三年是後
# ...

# %%
print(test_zh)
# Out:
# ['近人金靜庵說：「保藏之檔案謂之中，持中之人謂之史', '[140][141]\n\n農業有害生物包括雜草、昆蟲、蟎蟲、病原體等對作物生長造成不利影響的生物', '[148]\n\n國際食物政策研究所在2014年的研究報告中指出，現代科技與農業的結合可在未來顯著提高食物產量', '該用語於1999年，由法國國家農業研究院化學家艾維·蒂斯提出，以區分他和前牛津大學物理學家尼古拉斯·屈爾蒂於1988年提出的用語「分子料理」（Molecular gastronomy，為一科研活動）', '[19]在南美洲安地斯山脈，人們在10,000-7,000年前馴化了馬鈴薯，後續又馴化了豆子、古柯、羊駝、大羊駝和豚鼠', "\n早期[編輯]\n\n    早期電影拍攝描述的是日常生活，包括由路易斯·普林斯拍攝的《郎德海花園場景》以及盧米埃爾兄弟拍攝的Repas de bébé（1895）、Exiting the Factory（1895）、Démolition d'un mur（1895）、L'Arrivée d'un train en gare de La Ciotat（1895）、L'Arroseur Arrosé（1895）等等", '[130]混合畜牧業使用草地放養動物，但也輔以草料或糧食作為反芻和單胃動物（主要是牛和雞）的飼料', '\n\n歷史的組織方式有多種，包括按時間順序，文化，按地區和按主題排列', '[201]有人提出推力-拉力害蟲控制策略，藉助作物間種方式，利用部分植物的特殊氣味驅趕害蟲（推力），並將其引誘至方便移除的位置（拉力）', '[185]\n\n因為氣候變遷，過去某地罕見的有害生物與疾病可能會變得流行', '[223][224]\n塑料污染[編輯]\n\n塑料在農業中應用廣泛，用途包括增加作物產量，最佳化水資源和化學產品利用率', '[44]環境歷史學家威廉·克羅農提出了三種方法來消除偏見並確保真實準確的敘述：敘述不得與已知事實相牴觸，它們必須具有生態意義（特別是針對環境歷史），發表的著作必須經過學術界和其他歷史學家的審查才能確保問責制', '[55]北美東部原住民馴化了向日葵、菸草[56]、南瓜和藜屬作物[57][58]，人們也從野外採集野生稻米和楓糖', '\n詞源\n\n「歷史」的含義在中文中最早僅用「史」一字來代表', '為了回應馬克思主
# ...

# %%
print(train_zh)
# Out:
# ['\n世界上第一部電影--《郎德海花園場景》\n1912年的動畫短片《蚊子是怎麼生活的》是歷史上最早的動畫電影之一\n時長：10 分，13 秒', '\n卓別林的電影《債券》\n\n電影（英語：movie/ film），特點是運動／移動的畫面（英語：motion/ moving picture），是一種視覺藝術作品，用來模擬透過使用動態圖像來傳達思想、故事、感知、感覺、美或氛圍的體驗', '傳統對電影中運動感知的理解是因為視覺暫留，使得圖像離開後，仍能在眼睛保留「視像」約十分之一秒', '因此大腦感覺到圖像是「運動」的', '\n\n電影製作本身是藝術也是產業', '電影技術發展初期有各種不同的放映速度，但現時電影都多以每秒二十四格圖像作放映標準[2]', '\n\n路易斯·普林斯於1888年10月14日，使用改進版的單鏡頭攝影機（即MkII）拍攝了電影《朗德海花園場景》', '他在里茲的漢斯萊特區的惠特利工廠以及惠特利位於朗德海的家--奧克伍德農莊展出了他這第一部電影', '\n\n電影成為第七藝術的來由是義大利詩人和電影先驅者喬托·卡努杜（Ricciotto Canudo），他在於1911年發表的一篇《第六藝術的誕生》（Birth of the 6th art），將電影放在建築、雕塑、繪畫、音樂、詩之後，他後來又加入了早在電影之前就有的舞蹈，因此電影就成為第七藝術[3]', '\n\n如今，許多電影仍然用能把影像記錄到膠捲上的攝影機來拍攝', '膠卷經過沖洗之後，再用放映機來運行膠卷', '放映機可以發出光線，透過膠卷，這樣影像就在銀幕上顯示出了', '最近許多電影都用數位攝像機來拍攝，放映的時候，可以用數位放映機，也可以把數位影像轉置到傳統的膠片上', '這種方法可避免膠片長時間存放的失真', '但在這之前埃德沃德·邁布里奇在1878年拍攝的Sallie Gardner at a Gallop有時也被視為早期電影的先驅', '\n\n歷史[編輯]\n初期[編輯]\n\n1895年，「火車進站」是盧米埃兄弟製作的黑白無聲的紀錄片', '這部紀錄火車駛抵希歐達（la Ciotat）車站的影片，是架在月台上所拍攝的', '同年，盧米埃兄弟亦映演「離開工廠」，一套真正有演員演出的電影出現，拍攝當時工人下班的景象', '\n    停機再拍的發現者：喬治·梅里愛\
# ...

# %%
import math
import argparse
import sys
import os

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, HashingVectorizer
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.mixture import GaussianMixture

import nltk  # Bibliothèque pour le traitement du langage naturel
nltk.download('stopwords')
from scipy.sparse import csr_matrix
import numpy as np

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
# Out:
# [nltk_data] Downloading package stopwords to /home/ngauv-
# [nltk_data]     nicolas/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Modèle de mélange génératif supervisé

# %%
# On a trois ensembles d'entraînement pour chaque langue : train_fr, train_en, train_zh
# Et une liste de langues correspondantes : ['fr', 'en', 'zh']

# Créer des listes vides pour stocker les données d'entraînement combinées et les étiquettes de langue
combined_train_data = []
labels_train = []

# Parcourir chaque ensemble de données d'entraînement
for lang, train_set in zip(['FRENCH', 'ENGLISH', 'CHINESE_ZH'], [train_fr, train_en, train_zh]):
    # Pour chaque phrase dans l'ensemble de données d'entraînement actuel
    for sentence in train_set:
        # Ajouter la phrase à la liste principale de données d'entraînement combinées
        combined_train_data.append(sentence)
        # Ajouter l'étiquette de langue correspondante à la liste des étiquettes
        labels_train.append(lang)

# Vérifier que les données et les étiquettes sont bien combinées
print("Exemple de données d'entraînement combinées :", combined_train_data[:5])
print("Exemple d'étiquettes correspondantes :", labels_train[:5])
# Out:
# Exemple de données d'entraînement combinées : ["\nL’histoire est à la fois l'étude et l'écriture des faits et des événements passés quelles que soient leur variété et leurs complexités.", 'Ce mot est souvent écrit avec la première lettre en majuscule.', "On désigne aussi couramment sous le terme d'histoire (par synecdoque) le passé lui-même, comme dans les leçons de l'histoire.", "L'histoire est un récit écrit par lequel les êtres humains, et plus particulièrement les historiens, s'efforcent de faire connaître les temps révolus.", "Ces tentatives ne sont jamais entièrement indépendantes de conditionnements étrangers au domaine telle que la vision du monde de leur auteur ou sa culture, mais elles sont censées être élaborées à partir de sources plutôt que guidées par la spéculation ou l'idéologie."]
# Exemple d'étiquettes correspondantes : ['FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH']

# %%
# On a trois ensembles de tests pour chaque langue : train_fr, train_en, train_zh
# Et une liste de langues correspondantes : ['fr', 'en', 'zh']

# Créer des listes vides pour stocker les données de test combinées et les étiquettes de langue
combined_test_data = []
labels_test = []

# Parcourir chaque ensemble de données d'entraînement
for lang, test_set in zip(['FRENCH', 'ENGLISH', 'CHINESE_ZH'], [test_fr, test_en, test_zh]):
    # Pour chaque phrase dans l'ensemble de données d'entraînement actuel
    for sentence in test_set:
        # Ajouter la phrase à la liste principale de données d'entraînement combinées
        combined_test_data.append(sentence)
        # Ajouter l'étiquette de langue correspondante à la liste des étiquettes
        labels_test.append(lang)

# Vérifier que les données et les étiquettes sont bien combinées
print("Exemple de données d'entraînement combinées :", combined_test_data[:5])
print("Exemple d'étiquettes correspondantes :", labels_test[:5])
# Out:
# Exemple de données d'entraînement combinées : ['En outre, ce matériel publicitaire aidera l’exploitant à vendre des billets.', 'Cependant, il existe quelques prix qui félicitent le succès commercial, comme le Goldene Leinwand (la toile d’or) en Allemagne qui récompensait chaque film de plus de 3 000 000 de spectateurs[199].', "Il prend aussi le sens général d'histoire (au sens de récit), polysémie qu'il a conservée jusqu'à ce jour en français comme en allemand.", 'En 1956 est publiée une théorisation de la musique stochastique qui s’appuie entre autres sur la théorie des jeux de von Neumann.', 'Le son fut donc très vite intégré, de manière optique, sur le bord de la pellicule[253].']
# Exemple d'étiquettes correspondantes : ['FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH']

# %%
# Avec CountVectorizer (BoW Bag of Words)

class LanguageDetector_BoW:
    def __init__(self, n_features=256):
        self.vectorizer = CountVectorizer(analyzer='char', max_features=n_features)
        self.models = {}
        self.n_features = n_features

    def extract_features(self, texts):
        X = self.vectorizer.transform(texts)
        X = X.multiply(1 / X.sum(axis=1))  # Normalizing each row
        return X.tocsr()  # Convert to CSR format for better row slicing

    def train_gmm_models(self, data, labels, min_components=3):
        self.vectorizer.fit(data)
        features = self.extract_features(data)
        unique_labels = set(labels)
        for label in unique_labels:
            indices = np.where(np.array(labels) == label)[0]
            model_data = features[indices, :]  # Correct slicing using CSR matrix
            n_samples = model_data.shape[0]
            n_components = max(min_components, int(np.sqrt(n_samples) / 2))  # Dynamic number of components
            if n_samples < n_components:
                print(f"Not enough samples to train GMM for {label}. Required: {n_components}, Found: {n_samples}")
                continue
            gmm = GaussianMixture(n_components=n_components, covariance_type='full', random_state=42)
            gmm.fit(model_data.toarray())  # Need to convert to dense array for GMM fitting
            self.models[label] = gmm

    def predict_language(self, text):
        features = self.extract_features([text])
        best_label = None
        max_language_score = float('-inf')
        for label, model in self.models.items():
            language_score = model.score(features.toarray())  # Convert to dense array for scoring
            if language_score > max_language_score:
                max_language_score = language_score
                best_label = label
        return best_label

# %%
# Usage example

detector_BoW = LanguageDetector_BoW()
detector_BoW.train_gmm_models(combined_train_data, labels_train)

random_sentence = random.choice(combined_test_data)
predicted_language = detector_BoW.predict_language(random_sentence)
print(f"PREDICTED LANGUAGE OF '{random_sentence}' IS {predicted_language}.")
# Out:
# PREDICTED LANGUAGE OF 'Le cinéma allemand a également été révolutionné : un groupe de jeunes cinéastes s'est consacré à des innovations de style et de contenu dans le cinéma.' IS FRENCH.

# %%
labels_predicted = []
labels_language = set(labels_test)
compare = {}

for sentence in combined_test_data:
    predicted_language = detector_BoW.predict_language(sentence)
    labels_predicted.append(predicted_language)

for i, element in enumerate(labels_test):
    if labels_predicted[i] == element:
        compare[element] = compare.get(element, 0) + 1

for label in compare:
    print("Précision {label}: {score}".format(
        label = label,
        score = compare[label]/len([x for x in labels_predicted if x == label]))
        )
    
print("")
for label in compare:
    print("Rappel {label}: {score}".format(
        label=label,
        score=compare[label]/len([x for x in labels_test if x == label]))
        )
# Out:
# Précision FRENCH: 0.9909502262443439
# Précision ENGLISH: 0.9722222222222222
# Précision CHINESE_ZH: 1.0
#
# Rappel FRENCH: 0.9820627802690582
# Rappel ENGLISH: 0.9929078014184397
# Rappel CHINESE_ZH: 0.9937888198757764

# %%
print(labels_language)
# Out:
# {'ENGLISH', 'FRENCH', 'CHINESE_ZH'}

# %%
labels_languages = list(labels_language)

# %%
print(labels_languages)
# Out:
# ['ENGLISH', 'FRENCH', 'CHINESE_ZH']

# %%
# %matplotlib inline

cm = confusion_matrix(labels_test, labels_predicted, labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH'])  
ConfusionMatrixDisplay(cm, display_labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH']).plot()

# %%
# Un résultat équilibré : pratiquement parfait pour le chinois et l'anglais, un peu moins bien pour le français mais reste excellent

# %%
# Créer une instance du vectoriseur TF-IDF

class LanguageDetector_TFIDF:
    def __init__(self, n_features=256):
        self.vectorizer = TfidfVectorizer(analyzer='char', max_features=n_features)
        self.models = {}
        self.n_features = n_features

    def extract_features(self, texts):
        X = self.vectorizer.transform(texts)
        X = X.multiply(1 / X.sum(axis=1))  # Normalizing each row
        return X.tocsr()  # Convert to CSR format for better row slicing

    def train_gmm_models(self, data, labels, min_components=3):
        self.vectorizer.fit(data)
        features = self.extract_features(data)
        unique_labels = set(labels)
        for label in unique_labels:
            indices = np.where(np.array(labels) == label)[0]
            model_data = features[indices, :]  # Correct slicing using CSR matrix
            n_samples = model_data.shape[0]
            n_components = max(min_components, int(np.sqrt(n_samples) / 2))  # Dynamic number of components
            if n_samples < n_components:
                print(f"Not enough samples to train GMM for {label}. Required: {n_components}, Found: {n_samples}")
                continue
            gmm = GaussianMixture(n_components=n_components, covariance_type='full', random_state=42)
            gmm.fit(model_data.toarray())  # Need to convert to dense array for GMM fitting
            self.models[label] = gmm

    def predict_language(self, text):
        features = self.extract_features([text])
        best_label = None
        max_language_score = float('-inf')
        for label, model in self.models.items():
            language_score = model.score(features.toarray())  # Convert to dense array for scoring
            if language_score > max_language_score:
                max_language_score = language_score
                best_label = label
        return best_label

# %%
# # Usage example

detector_TFIDF = LanguageDetector_TFIDF()
detector_TFIDF.train_gmm_models(combined_train_data, labels_train)

random_sentence = random.choice(combined_test_data)
predicted_language = detector_TFIDF.predict_language(random_sentence)
print(f"PREDICTED LANGUAGE OF '{random_sentence}' IS {predicted_language}.")
# Out:
# PREDICTED LANGUAGE OF '而自20世紀以來，已開發國家逐漸以機械自動化裝置取代農業中的人工勞作，並利用合成肥料、殺蟲劑和選擇育種協助農業工作' IS CHINESE_ZH.

# %%
labels_predicted = []
labels_language = set(labels_test)
compare = {}

for sentence in combined_test_data:
    predicted_language = detector_TFIDF.predict_language(sentence)
    labels_predicted.append(predicted_language)

for i, element in enumerate(labels_test):
    if labels_predicted[i] == element:
        compare[element] = compare.get(element, 0) + 1

for label in compare:
    print("Précision {label}: {score}".format(
        label = label,
        score = compare[label]/len([x for x in labels_predicted if x == label]))
        )
    
print("")
for label in compare:
    print("Rappel {label}: {score}".format(
        label=label,
        score=compare[label]/len([x for x in labels_test if x == label]))
        )
# Out:
# Précision FRENCH: 0.9819819819819819
# Précision ENGLISH: 0.9647887323943662
# Précision CHINESE_ZH: 1.0
#
# Rappel FRENCH: 0.9775784753363229
# Rappel ENGLISH: 0.9716312056737588
# Rappel CHINESE_ZH: 1.0

# %%
# %matplotlib inline

cm2 = confusion_matrix(labels_test, labels_predicted, labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH'])  
ConfusionMatrixDisplay(cm2, display_labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH']).plot()

# %%
# Un résultat équilibré : parfait pour le chinois, un peu moins bien pour l'anglais et le français mais reste excellent

# %%
# Extraire les caractéristiques
tfidf_vectorizer = TfidfVectorizer()
bow_vectorizer = CountVectorizer()

# On recupère le contenu textuel de chaque set
#combined_train_data_text
#combined_test_data


# On vectorise avec count_vectorizer
X_train_bow = bow_vectorizer.fit_transform(combined_train_data)
X_test_bow = bow_vectorizer.transform(combined_test_data)

# On vectorise avec tfidf_vectorizer
X_train_tfidf = tfidf_vectorizer.fit_transform(combined_train_data)
X_test_tfidf = tfidf_vectorizer.transform(combined_test_data)

# On recupère le label "rating" de chaque set
#labels_train
#labels_test

# %%
# Modèle basé sur des machines à vecteurs de support (SVM) (modèle d'apprentissage supervisé) avec SVC (Support Vector Classifier)

# %%
# Entraîner le modèle SVC sur les caractéristiques TF-IDF
clf_svc_tfidf = LinearSVC().fit(X_train_tfidf, labels_train)
# Out:
# /home/ngauv-nicolas/miniconda3/envs/tal-ml/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
#Score avec tfidf
print(clf_svc_tfidf.score(X_test_tfidf, labels_test))
# Out:
# 0.9866666666666667

# %%
#Predict avec tfidf
print("predictions:", clf_svc_tfidf.predict(X_test_tfidf))
# Out:
# predictions: ['FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'CHINESE_ZH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
# ...

# %%
#Donnee
print("vraies classes:",labels_test)
# Out:
# vraies classes: ['FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', 'FRENCH', '
# ...

# %%
pred_svc_tfidf = clf_svc_tfidf.predict(X_test_tfidf)

# %%
# Visualisation des résultats
cm3 = confusion_matrix(labels_test, pred_svc_tfidf, labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH'])
ConfusionMatrixDisplay(cm3, display_labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH']).plot()

# %%
# Entraîner le modèle SVC sur les caractéristiques BoW (Bag of Words)
clf_svc_bow = LinearSVC().fit(X_train_bow, labels_train)
# Out:
# /home/ngauv-nicolas/miniconda3/envs/tal-ml/lib/python3.10/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
#Score avec BoW (Bag of Words)
print(clf_svc_bow.score(X_test_bow, labels_test))
# Out:
# 0.9866666666666667

# %%
#Predict avec BoW (Bag of Words)
print("predictions:", clf_svc_bow.predict(X_test_bow))
# Out:
# predictions: ['FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'CHINESE_ZH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
# ...

# %%
pred_svc_bow = clf_svc_bow.predict(X_test_bow)

# %%
# Visualisation des résultats
cm4 = confusion_matrix(labels_test, pred_svc_bow, labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH'])
ConfusionMatrixDisplay(cm4, display_labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH']).plot()

# %%
# Ici on remarque que contrairement au modele de mélange génératif supervisé (mélange Gaussien), 
# avec SVC et un modèle SVM on obtient les mêmes résultats qu'on utilise les caractéristiques TF-IDF ou Bag of Words
# Résultats avec SVC équilibré : très peu d'erreurs que ce soit pour le français, l'anglais ou le chinois
    # Qualité des résultats à peu près équivalent au modèle de mélange génératif supervisé (modèle de mélange Gaussien)

# %%
# Modèle basé sur MultinomialNB (Naive Bayes multinomial)

# %%
# Entraîner le modèle basé sur MultinomialNB (Naive Bayes multinomial) avec les caractéristiques TF-IDF
clf_multinb_tfidf = MultinomialNB().fit(X_train_tfidf, labels_train)

# %%
#Score avec tfidf
print(clf_multinb_tfidf.score(X_test_tfidf, labels_test))
# Out:
# 0.7980952380952381

# %%
#Predict avec tfidf
print("predictions:", clf_multinb_tfidf.predict(X_test_tfidf))
# Out:
# predictions: ['FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
# ...

# %%
pred_multinb_tfidf = clf_multinb_tfidf.predict(X_test_tfidf)

# %%
# Visualisation des résultats
cm5 = confusion_matrix(labels_test, pred_multinb_tfidf, labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH'])
ConfusionMatrixDisplay(cm5, display_labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH']).plot()

# %%
# Entraîner le modèle basé sur MultinomialNB (Naive Bayes multinomial) avec les caractéristiques BoW (Bag of Words)
clf_multinb_bow = MultinomialNB().fit(X_train_bow, labels_train)

# %%
#Score avec BoW (Bag of Words)
print(clf_multinb_bow.score(X_test_bow, labels_test))
# Out:
# 0.8095238095238095

# %%
#Predict avec bow
print("predictions:", clf_multinb_bow.predict(X_test_bow))
# Out:
# predictions: ['FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
# ...

# %%
pred_multinb_bow = clf_multinb_bow.predict(X_test_bow)

# %%
# Visualisation des résultats
cm6 = confusion_matrix(labels_test, pred_multinb_bow, labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH'])
ConfusionMatrixDisplay(cm6, display_labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH']).plot()

# %%
# Résultats très nuls avec un modèle basé sur MultinomialNB (Naive Bayes multinomial) pour le chinois, mais excellent pour l'anglais et parfait pour le français 
# et des différences selon les utilisation des caractéristiques TF-IDF ou BoW (Bag of Words)
# Score plus élevé et résultats très légèrement meilleurs avec BoW (Bag of Words)

# %%
# Modèle basé sur DecisionTreeClassifier (Arbres de décision)

# %%
# Entraîner le modèle basé sur DecisionTreeClassifier (Arbres de décision) avec les caractéristiques TF-IDF
clf_decisiontree_tfidf = DecisionTreeClassifier().fit(X_train_tfidf, labels_train)

# %%
#Score avec tfidf
print(clf_decisiontree_tfidf.score(X_test_tfidf, labels_test))
# Out:
# 0.758095238095238

# %%
#Predict avec tfidf
print("predictions:", clf_decisiontree_tfidf.predict(X_test_tfidf))
# Out:
# predictions: ['FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
# ...

# %%
pred_decisiontree_tfidf = clf_decisiontree_tfidf.predict(X_test_tfidf)

# %%
# Visualisation des résultats
cm7 = confusion_matrix(labels_test, pred_decisiontree_tfidf, labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH'])
ConfusionMatrixDisplay(cm7, display_labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH']).plot()

# %%
# Entraîner le modèle basé sur DecisionTreeClassifier (Arbres de décision) avec les caractéristiques BoW (Bag of Words)
clf_decisiontree_bow = DecisionTreeClassifier().fit(X_train_bow, labels_train)

# %%
#Score avec BoW (Bag of Words)
print(clf_decisiontree_bow.score(X_test_bow, labels_test))
# Out:
# 0.758095238095238

# %%
#Predict avec bow
print("predictions:", clf_decisiontree_bow.predict(X_test_bow))
# Out:
# predictions: ['FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
# ...

# %%
pred_decisiontree_bow = clf_decisiontree_bow.predict(X_test_bow)

# %%
# Visualisation des résultats
cm8 = confusion_matrix(labels_test, pred_decisiontree_bow, labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH'])
ConfusionMatrixDisplay(cm8, display_labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH']).plot()

# %%
# Résultats très nuls avec un modèle basé sur DecisionTreeClassifier (Arbres de décision) pour le chinois, mais excellent pour l'anglais et pratiquement parfait pour le français
# et des différences mineures selon les utilisation des caractéristiques TF-IDF ou BoW (Bag of Words)
# Score équivalents et résultats très ressemblants entre TF-IDF ou BoW (Bag of Words)

# %%
# Modèle basé sur RandomForestClassifier (Forêts aléatoires)

# %%
# Entraîner le modèle basé sur RandomForestClassifier (Forêts aléatoires) avec les caractéristiques TF-IDF
clf_randforest_tfidf = RandomForestClassifier().fit(X_train_tfidf, labels_train)

# %%
#Score avec tfidf
print(clf_randforest_tfidf.score(X_test_tfidf, labels_test))
# Out:
# 0.7561904761904762

# %%
#Predict avec tfidf
print("predictions:", clf_randforest_tfidf.predict(X_test_tfidf))
# Out:
# predictions: ['FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
# ...

# %%
pred_randforest_tfidf = clf_randforest_tfidf.predict(X_test_tfidf)

# %%
# Visualisation des résultats
cm9 = confusion_matrix(labels_test, pred_randforest_tfidf, labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH'])
ConfusionMatrixDisplay(cm9, display_labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH']).plot()

# %%
# Entraîner le modèle basé sur RandomForestClassifier (Forêts aléatoires) avec les caractéristiques BoW (Bag of Words)
clf_randforest_bow = RandomForestClassifier().fit(X_train_bow, labels_train)

# %%
#Score avec BoW (Bag of Words)
print(clf_randforest_bow.score(X_test_bow, labels_test))
# Out:
# 0.758095238095238

# %%
#Predict avec bow
print("predictions:", clf_randforest_bow.predict(X_test_bow))
# Out:
# predictions: ['FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
#  'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH' 'FRENCH'
# ...

# %%
pred_randforest_bow = clf_randforest_bow.predict(X_test_bow)

# %%
# Visualisation des résultats
cm10 = confusion_matrix(labels_test, pred_randforest_bow, labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH'])
ConfusionMatrixDisplay(cm10, display_labels=['FRENCH', 'ENGLISH', 'CHINESE_ZH']).plot()

# %%
# Résultats très nuls avec un modèle basé sur RandomForestClassifier (Forêts aléatoires) pour le chinois, mais excellent pour l'anglais et parfait pour le français
# et des différences mineures selon les utilisation des caractéristiques TF-IDF ou BoW (Bag of Words)
# Score plus élevé avec BoW (Bag of Words) et résultats très ressemblants entre TF-IDF ou BoW (Bag of Words)
# Pour l'instant, c'est avec ce modèle qu'on a les résultats les plus faibles

# %%
pred = clf.predict(X_test)
    
# Visualisation des résultats
cm = confusion_matrix(test_labels, pred, labels=clf.classes_)
disp = ConfusionMatrixDisplay(cm, display_labels=clf.classes_).plot()
disp.plot()

# %%
# Sauvegarde de la figure
plt.savefig(f'../Output/{args.vectorize}-{args.model}.png')
